# %% [markdown]
# # Analyzing numbers of tourists visiting Turkey 2006-2016
#
# This analysis is based on data published by Turkish Statistical Institute on http://www.turkstat.gov.tr/ .

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('Number of Person by Nationality.xls')

# %% [markdown]
# You can find this file in my repo

# %%
df.columns
# Out:
# Index(['Milliyetlerine Göre Çıkış Yapan Ziyaretçi Sayısı, 2006-2016',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='object')

# %%
df.head()
# Out:
#   Milliyetlerine Göre Çıkış Yapan Ziyaretçi Sayısı, 2006-2016      Unnamed: 1  \
# 0         Number of Person by Nationality, 2006-2016                      NaN
# 1                                           Milliyet           Yıllar - Years
# 2                                        Nationality                     2006
# 3                                     Toplam - Total                 23148670
# 4                                       A.B.D. - USA                   491977
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0         NaN         NaN         NaN        NaN        NaN        NaN
# 1         NaN         NaN         NaN        NaN        NaN        NaN
# 2      2007.0      2008.0      2009.0       2010       2011       2012
# 3  27214985.0  30979980.0  31972375.0   33027942   36151327   36463918
# 4    586774.0    607453.0    614025.0     595507     711608     714398
#
#     Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11
# ...

# %%
df
# Out:
#    Milliyetlerine Göre Çıkış Yapan Ziyaretçi Sayısı, 2006-2016  \
# 0          Number of Person by Nationality, 2006-2016
# 1                                            Milliyet
# 2                                         Nationality
# 3                                      Toplam - Total
# 4                                        A.B.D. - USA
# 5                                   Almanya - Germany
# 6                              Avustralya - Australia
# 7                                 Avusturya - Austria
# 8                             Azerbaycan - Azerbaijan
# 9                                   Belçika - Belgium
# 10                             Bulgaristan - Bulgaria
# 11                                Danimarka - Denmark
# 12                                    Fransa - France
# 13                                Gürcistan - Georgia
# 14                             Hollanda - Netherlands
# 15                         İngiltere - United Kingdom
# ...

# %%
df.iloc[:,0]
# Out:
# 0            Number of Person by Nationality, 2006-2016
# 1                                              Milliyet
# 2                                           Nationality
# 3                                        Toplam - Total
# 4                                          A.B.D. - USA
# 5                                     Almanya - Germany
# 6                                Avustralya - Australia
# 7                                   Avusturya - Austria
# 8                               Azerbaycan - Azerbaijan
# 9                                     Belçika - Belgium
# 10                               Bulgaristan - Bulgaria
# 11                                  Danimarka - Denmark
# 12                                      Fransa - France
# 13                                  Gürcistan - Georgia
# 14                               Hollanda - Netherlands
# 15                           İngiltere - United Kingdom
# 16                                          İran - Iran
# ...

# %% [markdown]
# # I'm going to plot numbers of US visitors to Turkey

# %%
year = df.iloc[2,1:]

# %%
usa = df.iloc[4,1:]

# %%
usa
# Out:
# Unnamed: 1     491977
# Unnamed: 2     586774
# Unnamed: 3     607453
# Unnamed: 4     614025
# Unnamed: 5     595507
# Unnamed: 6     711608
# Unnamed: 7     714398
# Unnamed: 8     739494
# Unnamed: 9     740755
# Unnamed: 10    755461
# Unnamed: 11    438581
# Name: 4, dtype: object

# %%
year.tolist()
# Out:
# [2006, 2007.0, 2008.0, 2009.0, 2010, 2011, 2012, 2013, 2014, 2015, 2016]

# %%
usa.tolist()
# Out:
# [491977,
#  586774.0,
#  607453.0,
#  614025.0,
#  595507,
#  711608,
#  714398,
#  739494,
#  740755,
#  755461,
#  438581]

# %%
print(len(usa))
print(len(year))
# Out:
# 11
# 11

# %%
cb_orange = (255/255, 128/255, 14/255)
plt.plot(year,usa,c=cb_orange, linewidth=3)
plt.title('USA')
plt.show()

# %% [markdown]
# # We can see there is a sharp drop in visitors starting 2015 due to the unrest in Syria and the political turmoil in Turkey.

# %%
countries = []
for i in df.iloc[:,0]:
    countries.append(i)

# %%
countries= countries[4:-15]

# %%
countries
# Out:
# ['A.B.D. - USA',
#  'Almanya - Germany',
#  'Avustralya - Australia',
#  'Avusturya - Austria',
#  'Azerbaycan - Azerbaijan',
#  'Belçika - Belgium',
#  'Bulgaristan - Bulgaria',
#  'Danimarka - Denmark',
#  'Fransa - France',
#  'Gürcistan - Georgia',
#  'Hollanda - Netherlands',
#  'İngiltere - United Kingdom',
#  'İran - Iran',
#  'İspanya - Spain',
#  'İsrail - Israel',
#  'İsveç - Sweden',
#  'İsviçre - Switzerland',
#  'İtalya - Italy',
#  'Japonya - Japan',
#  'Kanada - Canada',
#  'Rusya Federasyonu  \nRussian Federation',
#  'Suriye - Syria',
#  'Tunus - Tunisia',
#  'Türkiye (1) - Turkey (1)',
#  'Ukrayna - Ukraine',
#  'Yunanistan - Greece',
#  'Afrika ülkeleri  \nAfrican countries',
#  'Amerika ülkeleri  \nAmerican countries',
#  'Bağımsız Devletler Topluluğu  \nCom. Of Independent States',
#  'Batı Asya ülkeleri  \nWest Asian countries',
#  'Diğer Avrupa ülkeleri  \nOther European contries',
#  'Doğu Asya ülkeleri  \nEast Asian countries',
# ...

# %%
print(len(countries))
# Out:
# 36

# %%
countries_visitors = df.iloc[2:40,:]
countries_visitors.iloc[35] = countries_visitors.iloc[36]
# Out:
# C:\Users\Tam\Anaconda3\lib\site-packages\pandas\core\indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
countries_visitors
# Out:
#    Milliyetlerine Göre Çıkış Yapan Ziyaretçi Sayısı, 2006-2016 Unnamed: 1  \
# 2                                         Nationality                2006
# 3                                      Toplam - Total            23148670
# 4                                        A.B.D. - USA              491977
# 5                                   Almanya - Germany             3040595
# 6                              Avustralya - Australia               89362
# 7                                 Avusturya - Austria              318937
# 8                             Azerbaycan - Azerbaijan              370911
# 9                                   Belçika - Belgium              326891
# 10                             Bulgaristan - Bulgaria             1129938
# 11                                Danimarka - Denmark              191014
# 12                                    Fransa - France              503115
# 13                                Gürcistan - Georgia              531029
# ...

# %%
rows = [countries_visitors.loc[i].tolist() for i in range(3,39)]
rows[0]
# Out:
# ['Toplam - Total',
#  23148670,
#  27214985.0,
#  30979980.0,
#  31972375.0,
#  33027942,
#  36151327,
#  36463918,
#  39226226.4366,
#  41415070,
#  41617531,
#  31365330]

# %% [markdown]
# # Here we convert the dataframe into a list using list comprehension so that it can be easier for us to plot it .

# %%
years = countries_visitors.iloc[0,:].tolist()
years
len(years)
# Out:
# 12

# %%
for row in rows : 
    plt.plot(years[1:],row[1:],c=cb_orange, linewidth=3)
    plt.title(row[0])
    plt.show()

# %%
Ukraine = countries_visitors.iloc[26,1:]
Ukraine = Ukraine.tolist()

# %%
Ukraine
# Out:
# [426305,
#  462821.0,
#  574923.0,
#  460980.0,
#  455159,
#  489140,
#  496190,
#  598668,
#  538337,
#  602057,
#  812042]

# %%
cb_dark_blue = (0/255,107/255,164/255)
plt.plot(year,Ukraine,c=cb_dark_blue,linewidth=3)
plt.title('Ukraine')
plt.show()

# %% [markdown]
# # Ukraine is an interesting case because numbers of visitors from most of the countries have dropped after 2015 , while Ukraine's numbers have risen in the designated time frame .

# %%
Tunisia = countries_visitors.iloc[24,1:]

# %%
Tunisia.tolist()
# Out:
# [45270,
#  35507.0,
#  39724.0,
#  53891.0,
#  51160,
#  62018,
#  76552,
#  82190,
#  91053,
#  97873,
#  92691]

# %%
plt.plot(year,Tunisia,c=cb_dark_blue,linewidth=3)
plt.title('Tunisia')
plt.show()

# %% [markdown]
# # Tunisia is another interesting case since it too has seen a rise in numbers of visitors .

# %%
countries_visitors['Unnamed: 11'].sort_values(ascending=False)
# Out:
# 3     31365330
# 27     5137239
# 5      3300838
# 13     2177824
# 10     1598103
# 16     1574216
# 33     1528993
# 15     1416628
# 34      980075
# 28      812042
# 38      801298
# 37      801298
# 32      777379
# 14      717535
# 24      683335
# 29      568802
# 8       541990
# 30      501640
# 12      478107
# 4       438581
# 9       313677
# 11      284392
# 19      260024
# 7       256253
# 18      240515
# 35      214519
# 21      208773
# 39      206367
# 20      186868
# 36      170173
# 31      168726
# 25      167563
# 23      103154
# 17      102109
# 6        96972
# 26       92691
# 22       47034
# 2         2016
# Name: Unnamed: 11, dtype: object

# %%
countries_visitors['Unnamed: 10'].sort_values(ascending=False)
# Out:
# 3     41617531
# 27     5017086
# 5      4724787
# 24     2842972
# 15     2094736
# 33     1914673
# 13     1872325
# 10     1751766
# 37     1693028
# 38     1693028
# 16     1581644
# 34     1284671
# 32     1072077
# 14      943907
# 4       755461
# 29      737562
# 12      715990
# 30      687824
# 28      602057
# 8       548579
# 19      523844
# 21      467470
# 9       458168
# 7       394607
# 35      365302
# 11      344033
# 25      325259
# 20      324416
# 39      291928
# 31      264042
# 6       224566
# 17      219993
# 36      218223
# 18      205897
# 23      173410
# 22      104308
# 26       97873
# 2         2015
# Name: Unnamed: 10, dtype: object

# %%
countries_visitors['Unnamed: 9'].sort_values(ascending=False)
# Out:
# 3     41415070
# 27     4480576
# 5      4349969
# 24     3451749
# 15     2098621
# 13     1718167
# 37     1714491
# 38     1714491
# 33     1617012
# 10     1609660
# 16     1452258
# 34     1210258
# 32     1084426
# 14     1019329
# 12      856077
# 29      807524
# 4       740755
# 30      692480
# 21      640595
# 8       590321
# 19      541267
# 28      538337
# 9       499674
# 7       408021
# 11      336710
# 20      323120
# 39      266059
# 25      265391
# 35      260248
# 17      256887
# 31      209562
# 6       193033
# 36      191173
# 23      175274
# 18      172823
# 22      168399
# 26       91053
# 2         2014
# Name: Unnamed: 9, dtype: object

# %%
countries_visitors['Unnamed: 8'].sort_values(ascending=False)
# Out:
# 3     3.92262e+07
# 27        4254393
# 5         4193043
# 24        3049035
# 15        1963559
# 13        1732706
# 37        1581428
# 38        1581428
# 10        1491433
# 33        1280151
# 16        1081626
# 34        1075917
# 14        1001905
# 32         938400
# 12         856172
# 4          739494
# 29         674367
# 21         661663
# 30         599575
# 28         598668
# 8          568474
# 19         553897
# 9          480148
# 7          396921
# 11         350081
# 20         324850
# 17         259067
# 31         227118
# 39         224412
# 25         191773
# 23         183993
# 6          180692
# 35         179860
# 22         172469
# 36         151882
# 18         129414
# 26          82190
# 2            2013
# Name: Unnamed: 8, dtype: object

# %%
countries_visitors['Unnamed: 7'].sort_values(ascending=False)
# Out:
# 3     36463918
# 5      4224978
# 27     4066157
# 24     2647090
# 15     1934775
# 37     1532896
# 38     1532896
# 10     1406392
# 13     1364945
# 16     1073779
# 33     1053894
# 14      993179
# 34      990570
# 12      875035
# 32      822251
# 4       714398
# 21      645757
# 29      624536
# 30      527781
# 8       523486
# 28      496190
# 19      463166
# 9       462201
# 7       400706
# 25      298455
# 20      292264
# 11      284393
# 17      255153
# 39      207007
# 22      196586
# 31      170056
# 23      167576
# 6       156540
# 35      148225
# 36      118610
# 18       87951
# 26       76552
# 2         2012
# Name: Unnamed: 7, dtype: object

# %%
countries_visitors.iloc[8,:]
#Identify the countries with the highest numbers using their index .
# Out:
# Milliyetlerine Göre Çıkış Yapan Ziyaretçi Sayısı, 2006-2016    Bulgaristan - Bulgaria
# Unnamed: 1                                                                    1129938
# Unnamed: 2                                                                1.23962e+06
# Unnamed: 3                                                                1.36924e+06
# Unnamed: 4                                                                1.52381e+06
# Unnamed: 5                                                                    1388381
# Unnamed: 6                                                                    1384137
# Unnamed: 7                                                                    1406392
# Unnamed: 8                                                                    1491433
# Unnamed: 9                                                                    1609660
# Unnamed: 10                                                                   1751766
# ...

# %% [markdown]
# # In 2016 Germany came first with the highest number of visitors , followed by Gerorgia , followed by Bulgaria. over the years it looks Germany has the highest numbers of tourists visiting Turkey .

# %%
fig = plt.figure(figsize=(70,70))
plt.style.use('seaborn-darkgrid')
ax1 = fig.add_subplot(12,3,1)
ax1.plot(years[1:],rows[0][1:],c=cb_orange, linewidth=3)
ax1.set_title(rows[0][0])

ax2 = fig.add_subplot(12,3,2)
ax2.plot(years[1:],rows[1][1:],c=cb_orange, linewidth=3)
ax2.set_title(rows[1][0])

ax3 = fig.add_subplot(12,3,3)
ax3.plot(years[1:],rows[2][1:],c=cb_orange, linewidth=3)
ax3.set_title(rows[2][0])

ax4 = fig.add_subplot(12,3,4)
ax4.plot(years[1:],rows[3][1:],c=cb_orange, linewidth=3)
ax4.set_title(rows[3][0])

ax5 = fig.add_subplot(12,3,5)
ax5.plot(years[1:],rows[4][1:],c=cb_orange, linewidth=3)
ax5.set_title(rows[4][0])

ax6 = fig.add_subplot(12,3,6)
ax6.plot(years[1:],rows[5][1:],c=cb_orange, linewidth=3)
ax6.set_title(rows[5][0])

ax7 = fig.add_subplot(12,3,7)
ax7.plot(years[1:],rows[6][1:],c=cb_orange, linewidth=3)
ax7.set_title(rows[6][0])

ax8 = fig.add_subplot(12,3,8)
ax8.plot(years[1:],rows[7][1:],c=cb_orange, linewidth=3)
ax8.set_title(rows[7][0])

ax9 = fig.add_subplot(12,3,9)
ax9.plot(years[1:],rows[8][1:],c=cb_orange, linewidth=3)
ax9.set_title(rows[8][0])

ax10 = fig.add_subplot(12,3,10)
ax10.plot(years[1:],rows[9][1:],c=cb_orange, linewidth=3)
ax10.set_title(rows[9][0])

ax11 = fig.add_subplot(12,3,11)
ax11.plot(years[1:],rows[10][1:],c=cb_orange, linewidth=3)
ax11.set_title(rows[10][0])

ax12 = fig.add_subplot(12,3,12)
ax12.plot(years[1:],rows[11][1:],c=cb_orange, linewidth=3)
ax12.set_title(rows[11][0])

ax13 = fig.add_subplot(12,3,13)
ax13.plot(years[1:],rows[12][1:],c=cb_orange, linewidth=3)
ax13.set_title(rows[12][0])

ax14 = fig.add_subplot(12,3,14)
ax14.plot(years[1:],rows[13][1:],c=cb_orange, linewidth=3)
ax14.set_title(rows[13][0])

ax15 = fig.add_subplot(12,3,15)
ax15.plot(years[1:],rows[14][1:],c=cb_orange, linewidth=3)
ax15.set_title(rows[14][0])

ax16 = fig.add_subplot(12,3,16)
ax16.plot(years[1:],rows[15][1:],c=cb_orange, linewidth=3)
ax16.set_title(rows[15][0])

ax17 = fig.add_subplot(12,3,17)
ax17.plot(years[1:],rows[16][1:],c=cb_orange, linewidth=3)
ax17.set_title(rows[16][0])

ax18 = fig.add_subplot(12,3,18)
ax18.plot(years[1:],rows[17][1:],c=cb_orange, linewidth=3)
ax18.set_title(rows[17][0])

ax19 = fig.add_subplot(12,3,19)
ax19.plot(years[1:],rows[18][1:],c=cb_orange, linewidth=3)
ax19.set_title(rows[18][0])

ax20 = fig.add_subplot(12,3,20)
ax20.plot(years[1:],rows[19][1:],c=cb_orange, linewidth=3)
ax20.set_title(rows[19][0])

ax21 = fig.add_subplot(12,3,21)
ax21.plot(years[1:],rows[20][1:],c=cb_orange, linewidth=3)
ax21.set_title(rows[20][0])

ax22 = fig.add_subplot(12,3,22)
ax22.plot(years[1:],rows[21][1:],c=cb_orange, linewidth=3)
ax22.set_title(rows[21][0])

ax23 = fig.add_subplot(12,3,23)
ax23.plot(years[1:],rows[22][1:],c=cb_orange, linewidth=3)
ax23.set_title(rows[22][0])

ax24 = fig.add_subplot(12,3,24)
ax24.plot(years[1:],rows[23][1:],c=cb_orange, linewidth=3)
ax24.set_title(rows[23][0])

ax25 = fig.add_subplot(12,3,25)
ax25.plot(years[1:],rows[24][1:],c=cb_orange, linewidth=3)
ax25.set_title(rows[24][0])

ax26 = fig.add_subplot(12,3,26)
ax26.plot(years[1:],rows[25][1:],c=cb_orange, linewidth=3)
ax26.set_title(rows[25][0])

ax27 = fig.add_subplot(12,3,27)
ax27.plot(years[1:],rows[26][1:],c=cb_orange, linewidth=3)
ax27.set_title(rows[26][0])

ax28 = fig.add_subplot(12,3,28)
ax28.plot(years[1:],rows[27][1:],c=cb_orange, linewidth=3)
ax28.set_title(rows[27][0])

ax29 = fig.add_subplot(12,3,29)
ax29.plot(years[1:],rows[28][1:],c=cb_orange, linewidth=3)
ax29.set_title(rows[28][0])

ax30 = fig.add_subplot(12,3,30)
ax30.plot(years[1:],rows[29][1:],c=cb_orange, linewidth=3)
ax30.set_title(rows[29][0])

ax31 = fig.add_subplot(12,3,31)
ax31.plot(years[1:],rows[30][1:],c=cb_orange, linewidth=3)
ax31.set_title(rows[30][0])

ax32 = fig.add_subplot(12,3,32)
ax32.plot(years[1:],rows[31][1:],c=cb_orange, linewidth=3)
ax32.set_title(rows[31][0])

ax33 = fig.add_subplot(12,3,33)
ax33.plot(years[1:],rows[32][1:],c=cb_orange, linewidth=3)
ax33.set_title(rows[32][0])

ax34 = fig.add_subplot(12,3,34)
ax34.plot(years[1:],rows[33][1:],c=cb_orange, linewidth=3)
ax34.set_title(rows[33][0])

ax35 = fig.add_subplot(12,3,35)
ax35.plot(years[1:],rows[34][1:],c=cb_orange, linewidth=3)
ax35.set_title(rows[34][0])

ax36 = fig.add_subplot(12,3,36)
ax36.plot(years[1:],rows[35][1:],c=cb_orange, linewidth=3)
ax36.set_title(rows[35][0])
plt.show()
fig.savefig('plotting_all_countries.pdf')

# %% [markdown]
# # For better visualization of the data , we can plot all countries in a single figure so it's easier to spot patterns as shown in the previous cell .

# %%
print(plt.style.available)
# Out:
# ['seaborn-deep', 'seaborn-whitegrid', 'seaborn-bright', 'seaborn-muted', 'seaborn-talk', 'dark_background', 'grayscale', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-pastel', 'ggplot', 'seaborn-white', 'seaborn-darkgrid', 'classic', 'seaborn-notebook', 'bmh', 'seaborn-paper', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-poster', 'seaborn-colorblind']

# %%
highest_2016 = countries_visitors.sort_values('Unnamed: 11',ascending=False)

# %%
highest_2016
# Out:
#    Milliyetlerine Göre Çıkış Yapan Ziyaretçi Sayısı, 2006-2016 Unnamed: 1  \
# 3                                      Toplam - Total            23148670
# 27                           Türkiye (1) - Turkey (1)             3071716
# 5                                   Almanya - Germany             3040595
# 13                                Gürcistan - Georgia              531029
# 10                             Bulgaristan - Bulgaria             1129938
# 16                                        İran - Iran              604094
# 33         Batı Asya ülkeleri  \nWest Asian countries              365622
# 15                         İngiltere - United Kingdom             1309352
# 34   Diğer Avrupa ülkeleri  \nOther European contries              999055
# 28                                  Ukrayna - Ukraine              426305
# 37       OECD Ülkeleri(Diğer) \nOECD countries(other)              290650
# 38       OECD Ülkeleri(Diğer) \nOECD countries(other)              290650
# ...

# %%
highest_2016 = highest_2016.drop(highest_2016.index[10])

# %%
highest_2016
# Out:
#    Milliyetlerine Göre Çıkış Yapan Ziyaretçi Sayısı, 2006-2016 Unnamed: 1  \
# 3                                      Toplam - Total            23148670
# 27                           Türkiye (1) - Turkey (1)             3071716
# 5                                   Almanya - Germany             3040595
# 13                                Gürcistan - Georgia              531029
# 10                             Bulgaristan - Bulgaria             1129938
# 16                                        İran - Iran              604094
# 33         Batı Asya ülkeleri  \nWest Asian countries              365622
# 15                         İngiltere - United Kingdom             1309352
# 34   Diğer Avrupa ülkeleri  \nOther European contries              999055
# 28                                  Ukrayna - Ukraine              426305
# 38       OECD Ülkeleri(Diğer) \nOECD countries(other)              290650
# 32  Bağımsız Devletler Topluluğu  \nCom. Of Indepe...              435362
# ...

# %%
highest_10_2016 = highest_2016.iloc[2:11,0:2]

# %%
highest_10_2016.sort_values('Unnamed: 1',ascending=False).plot(kind='bar')

# %%
df2016=highest_10_2016.iloc[:,0]

# %%
highest_10_2016 = highest_10_2016.set_index(df2016)

# %%
highest_10_2016.sort_values('Unnamed: 1',ascending=False).plot(kind='bar')

# %%
df
# Out:
#    Milliyetlerine Göre Çıkış Yapan Ziyaretçi Sayısı, 2006-2016  \
# 0          Number of Person by Nationality, 2006-2016
# 1                                            Milliyet
# 2                                         Nationality
# 3                                      Toplam - Total
# 4                                        A.B.D. - USA
# 5                                   Almanya - Germany
# 6                              Avustralya - Australia
# 7                                 Avusturya - Austria
# 8                             Azerbaycan - Azerbaijan
# 9                                   Belçika - Belgium
# 10                             Bulgaristan - Bulgaria
# 11                                Danimarka - Denmark
# 12                                    Fransa - France
# 13                                Gürcistan - Georgia
# 14                             Hollanda - Netherlands
# 15                         İngiltere - United Kingdom
# ...

# %%
index = df.iloc[2,:]
df.columns = index

# %%
df = df.drop(df.index[0:2])

# %%
df
# Out:
# 2                                         Nationality      2006      2007.0  \
# 2                                         Nationality      2006      2007.0
# 3                                      Toplam - Total  23148670  27214985.0
# 4                                        A.B.D. - USA    491977    586774.0
# 5                                   Almanya - Germany   3040595   3498985.0
# 6                              Avustralya - Australia     89362    100879.0
# 7                                 Avusturya - Austria    318937    341842.0
# 8                             Azerbaycan - Azerbaijan    370911    395969.0
# 9                                   Belçika - Belgium    326891    398076.0
# 10                             Bulgaristan - Bulgaria   1129938   1239621.0
# 11                                Danimarka - Denmark    191014    216968.0
# 12                                    Fransa - France    503115    586907.0
# ...
